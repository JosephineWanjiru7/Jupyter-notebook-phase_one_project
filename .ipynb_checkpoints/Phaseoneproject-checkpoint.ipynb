# %% [markdown]
# Phase One Project Submission
#
# Please fill out:
#
# Student name: Josephine Gathenya
#
# Student pace: part time
#
# Scheduled project review date/time:
#
# Instructor name:
#
# Blog post URL:

# %% [markdown]
# PROJECT STATEMENT
#
# Microsoft Company would wish to join the creative movie industry by creating a new movie studio. They however do not have a background in creating movies and, would like to know, which films are performing the best at the Box Office.
#
# The objectives of this project are to use data analytic tools and techniques to gain useful insights and decision making that will help Microsoft to decide what type of films to create.

# %% [markdown]
# Important information I will need to know about the best performing films:
#
# The genres, the film titles, the ratings based on the viewership votes,the budgets used, and how much the films made as profit both locally and internationally.

# %% [markdown]
# FILES
#
# I will be working with the following files:
#
# imdb.title.basics
#
# imdb.title.ratings
#
# bom.movie_gross
#
# tn.movie_budgets

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is CEA5-6E23
#
#  Directory of C:\Users\lenovo\Desktop\Flatiron\Phase_one_project\Jupyter-notebook-phase_one_project
#
# 05/11/2023  23:59    <DIR>          .
# 05/11/2023  23:59    <DIR>          ..
# 04/11/2023  13:35    <DIR>          .ipynb_checkpoints
# 02/11/2023  19:37           142,555 bom.movie_gross.csv
# 05/11/2023  22:41            30,384 download (1).png
# 05/11/2023  23:27            11,084 download (2).png
# 05/11/2023  23:55            31,957 download (3).png
# 04/11/2023  22:27            18,476 download.png
# 02/11/2023  19:41        48,926,352 name.basics.csv
# 05/11/2023  23:59           358,945 Phaseoneproject.ipynb
# 03/11/2023  02:24                57 README.md
# 02/11/2023  19:37         1,184,685 rt.movie_info.tsv
# 02/11/2023  19:39         9,395,716 rt.reviews.tsv
# 02/11/2023  19:39        18,945,529 title.akas.csv
# 02/11/2023  19:39        11,852,240 title.basics.csv
# ...

# %%
# importing the needed libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#parsing csv/tsv files to pandas dataframe
title_basics = pd.read_csv('title.basics.csv')

# %%
title_ratings = pd.read_csv('title.ratings.csv')

# %%
bom_movie_gross = pd.read_csv('bom.movie_gross.csv')

# %%
movie_budgets = pd.read_csv('tn.movie_budgets.csv')

# %%
title_crew = pd.read_csv('title.crew.csv')

# %%
name_basics =  pd.read_csv('name.basics.csv')

# %%
#exploring the file data of the title.basics.csv
#first rows
title_basics.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %%
#rows and columns
title_basics.shape
# Out:
# (146144, 6)

# %%
title_basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   tconst           146144 non-null  object
#  1   primary_title    146144 non-null  object
#  2   original_title   146123 non-null  object
#  3   start_year       146144 non-null  int64
#  4   runtime_minutes  114405 non-null  float64
#  5   genres           140736 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 6.7+ MB

# %%
#summary of the all the data 
title_basics.describe
# Out:
# <bound method NDFrame.describe of            tconst                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# ...

# %%
#column names
title_basics.columns
# Out:
# Index(['tconst', 'primary_title', 'original_title', 'start_year',
#        'runtime_minutes', 'genres'],
#       dtype='object')

# %% [markdown]
# **There are 6 columns in this dataset**

# %%
#data types
title_basics.dtypes
# Out:
# tconst              object
# primary_title       object
# original_title      object
# start_year           int64
# runtime_minutes    float64
# genres              object
# dtype: object

# %%
#finding any missing values
title_basics.isna().sum()
# Out:
# tconst                 0
# primary_title          0
# original_title        21
# start_year             0
# runtime_minutes    31739
# genres              5408
# dtype: int64

# %% [markdown]
#    **There are missing values in the title_basics dataset and is as follows:**
#
# original_title        21
#
# runtime_minutes    31739
#
# genres              5408

# %%
#finding unique values
title_basics['original_title'].unique()
# Out:
# array(['Sunghursh', 'Ashad Ka Ek Din', 'The Other Side of the Wind', ...,
#        'Dankyavar Danka', '6 Gunn', 'Chico Albuquerque - Revelações'],
#       dtype=object)

# %%
len(title_basics['original_title'].unique())
# Out:
# 137774

# %% [markdown]
# **There are 137774 / 146144 unique values in the 'original_title'**

# %%
#finding duplicated values
duplicate_values = title_basics[title_basics.duplicated(subset='original_title', keep=False)]
duplicate_values
# Out:
#            tconst                     primary_title  \
# 6       tt0112502                           Bigfoot
# 19      tt0247643  Los pájaros se van con la muerte
# 21      tt0250404                         Godfather
# 30      tt0285252                    Life's a Beach
# 34      tt0297400                         Snowblind
# ...           ...                               ...
# 146117  tt9913418                         Fragments
# 146119  tt9913594                       Bacchanalia
# 146120  tt9913936                          Paradise
# 146125  tt9914642                         Albatross
# 146134  tt9916160                        Drømmeland
#
#                           original_title  start_year  runtime_minutes  \
# 6                                Bigfoot        2017              NaN
# 19      Los pájaros se van con la muerte        2011            110.0
# 21                             Godfather        2012              NaN
# ...

# %% [markdown]
# **there are 13751/146144 rows where values in the 'original_title'(dtype is an object) column are the same as the 'primary_title' column**

# %% [markdown]
# **WHAT TO DO WITH THE MISSING VALUES AND DUPLICATED VALUES?**

# %% [markdown]
# **I will DROP the 21/146144 rows with the missing values  in the 'original_title' column which represent about 0.01% of the whole dataset**
#
# **I will RETAIN the 13751/146144 rows with the duplicated values which represent about 9% of the whole dataset**
#
# **(they are in two different columns, could mean the primary title and the original title columns, had the same titles)**

# %%
#dropping the missing values
title_basics.dropna(subset = ['original_title'], inplace=True)

# %%
#checking the updated changes
title_basics
# Out:
#            tconst                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# ...

# %% [markdown]
# **there are 5408/146123 missing values in the 'genres' column which is about 4% of the whole dataset**
#
# **I will remove the rows with these values because it would be important information for me to know the genres of the films I will be analysing. Missing values would make it difficult to analyse and maybe group the commonest genres people like to watch.**

# %%
title_basics.dropna(subset = ['genres'], inplace=True)

# %%
title_basics
# Out:
#            tconst                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146138  tt9916428                          The Secret of China
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# ...

# %% [markdown]
# **the dataframe has now been updated**

# %%
title_basics.isna().sum()
# Out:
# tconst                 0
# primary_title          0
# original_title         0
# start_year             0
# runtime_minutes    28502
# genres                 0
# dtype: int64

# %% [markdown]
# **there are 28502/146123 missing values in the 'runtime_minutes' column(dtype is a float value) which is about 20% of the whole dataset**
#
# **I want to retain these rows because information on the runtimes would be helpful during analysis e.g when finding out whether the duration of the movie is a determining factor when choosing a film to watch**
#
# **i will replace the missing values with the median runtime minutes**

# %%
title_basics['runtime_minutes'].median()
# Out:
# 87.0

# %%
median_basics = 87.0
median_basics
# Out:
# 87.0

# %%
title_basics['runtime_minutes'].fillna(median_basics, inplace=True)

# %%
title_basics
# Out:
#            tconst                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146138  tt9916428                          The Secret of China
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# ...

# %%
title_basics.isna().sum()
# Out:
# tconst             0
# primary_title      0
# original_title     0
# start_year         0
# runtime_minutes    0
# genres             0
# dtype: int64

# %% [markdown]
# **The 'title.basics' dataset does not have any missing values now**

# %% [markdown]
# **TITLE RATINGS DATASET**

# %%
title_ratings.head()
# Out:
#        tconst  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21

# %%
title_ratings.shape
# Out:
# (73856, 3)

# %%
title_ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73856 entries, 0 to 73855
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tconst         73856 non-null  object
#  1   averagerating  73856 non-null  float64
#  2   numvotes       73856 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.7+ MB

# %%
title_ratings.describe
# Out:
# <bound method NDFrame.describe of            tconst  averagerating  numvotes
# 0      tt10356526            8.3        31
# 1      tt10384606            8.9       559
# 2       tt1042974            6.4        20
# 3       tt1043726            4.2     50352
# 4       tt1060240            6.5        21
# ...           ...            ...       ...
# 73851   tt9805820            8.1        25
# 73852   tt9844256            7.5        24
# 73853   tt9851050            4.7        14
# 73854   tt9886934            7.0         5
# 73855   tt9894098            6.3       128
#
# [73856 rows x 3 columns]>

# %%
title_ratings.columns
# Out:
# Index(['tconst', 'averagerating', 'numvotes'], dtype='object')

# %% [markdown]
# **There are 3 columns in this dataset**

# %%
title_ratings.dtypes
# Out:
# tconst            object
# averagerating    float64
# numvotes           int64
# dtype: object

# %%
title_ratings.isna().sum()
# Out:
# tconst           0
# averagerating    0
# numvotes         0
# dtype: int64

# %% [markdown]
# **There are no missing values in the title_ratings dataset**

# %% [markdown]
# **BOM MOVIE GROSS DATASET**

# %%
bom_movie_gross.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
bom_movie_gross.shape
# Out:
# (3387, 5)

# %%
bom_movie_gross.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
#  4   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %%
bom_movie_gross.describe
# Out:
# <bound method NDFrame.describe of                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
# ...

# %%
bom_movie_gross.columns
# Out:
# Index(['title', 'studio', 'domestic_gross', 'foreign_gross', 'year'], dtype='object')

# %% [markdown]
# **There are 5 columns in this dataset**

# %%
bom_movie_gross.dtypes
# Out:
# title              object
# studio             object
# domestic_gross    float64
# foreign_gross      object
# year                int64
# dtype: object

# %%
bom_movie_gross.isna().sum()
# Out:
# title                0
# studio               5
# domestic_gross      28
# foreign_gross     1350
# year                 0
# dtype: int64

# %% [markdown]
# **There are missing values in 3 of 5 columns of the bom_movie_gross dataset and is as follows:**
#
# studio               5
#
# domestic_gross      28
#
# foreign_gross     1350

# %% [markdown]
# **what to do with the missing values?**

# %% [markdown]
# **I will remove the 5/3387 rows with missing values in the 'studio' column(dtype is an object)**
#
# **I will also remove the 28/3387 rows with missing values in the 'domestic_gross' column(dtype is a floatvalue)**

# %%
#df = df.dropna(subset=[column_name])
bom_movie_gross.dropna(subset = ['studio', 'domestic_gross'], inplace=True)

# %%
bom_movie_gross
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# ...

# %% [markdown]
# **The resulting DataFrame will contain only rows where the two columns do not have any missing values**

# %%
bom_movie_gross.isna().sum()
# Out:
# title                0
# studio               0
# domestic_gross       0
# foreign_gross     1349
# year                 0
# dtype: int64

# %% [markdown]
# **notice the dataframe has been updated and there are no missing values in the 'studio' and 'domestic_gross' columns**

# %%
bom_movie_gross.dtypes
# Out:
# title              object
# studio             object
# domestic_gross    float64
# foreign_gross      object
# year                int64
# dtype: object

# %% [markdown]
# **converting object values to numeric values and removing comma values before replacing missing values with the median**

# %%
bom_movie_gross['foreign_gross'].str.replace(',', '').astype(float)
# Out:
# 0       652000000.0
# 1       691300000.0
# 2       664300000.0
# 3       535700000.0
# 4       513900000.0
#            ...
# 3382            NaN
# 3383            NaN
# 3384            NaN
# 3385            NaN
# 3386            NaN
# Name: foreign_gross, Length: 3356, dtype: float64

# %%
bom_movie_gross['foreign_gross'] = bom_movie_gross['foreign_gross'].str.replace(',', '').astype(float)

bom_movie_gross['foreign_gross']
# Out:
# 0       652000000.0
# 1       691300000.0
# 2       664300000.0
# 3       535700000.0
# 4       513900000.0
#            ...
# 3382            NaN
# 3383            NaN
# 3384            NaN
# 3385            NaN
# 3386            NaN
# Name: foreign_gross, Length: 3356, dtype: float64

# %%
bom_movie_gross
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#       foreign_gross  year
# ...

# %%
bom_movie_gross.dtypes
# Out:
# title              object
# studio             object
# domestic_gross    float64
# foreign_gross     float64
# year                int64
# dtype: object

# %%
bom_movie_gross.isna().sum()
# Out:
# title                0
# studio               0
# domestic_gross       0
# foreign_gross     1349
# year                 0
# dtype: int64

# %% [markdown]
# **What to do with the 1349/3356 missing values in the 'foreign_gross' column which is 40% of the whole data set?**

# %% [markdown]
# **I will replace the NaN values with the median value because the missing values make up  almost half all the data**

# %%
#finding the median in the 'foreign_gross'column
#df['Column1'].median()
bom_movie_gross['foreign_gross'].median()
# Out:
# 19400000.0

# %%
median= 19400000.0
median
# Out:
# 19400000.0

# %%
#checking also the mean

bom_movie_gross['foreign_gross'].mean()
# Out:
# 75790384.84130543

# %% [markdown]
# **replacing the 1349 values with the median**

# %%
#df[column_name].fillna(median, inplace=True)

bom_movie_gross['foreign_gross'].fillna(median, inplace=True)

# %%
bom_movie_gross
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#       foreign_gross  year
# ...

# %% [markdown]
# **the missing values in the 'foreign_gross' column have been updated with the median**

# %% [markdown]
# **this is the new dataframe with the updated changes on the 'foreign_gross' column**

# %%
#checking missing values in the dataset

bom_movie_gross.isna().sum()
# Out:
# title             0
# studio            0
# domestic_gross    0
# foreign_gross     0
# year              0
# dtype: int64

# %%
#checking the dtypes in the dataset
bom_movie_gross.dtypes
# Out:
# title              object
# studio             object
# domestic_gross    float64
# foreign_gross     float64
# year                int64
# dtype: object

# %% [markdown]
# **the 'bom_movie_gross' dataset is now clean**

# %% [markdown]
# **MOVIE BUDGETS DATASET**

# %%
movie_budgets.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
movie_budgets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   object
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   object
#  4   domestic_gross     5782 non-null   object
#  5   worldwide_gross    5782 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 271.2+ KB

# %%
movie_budgets.isna().sum()
# Out:
# id                   0
# release_date         0
# movie                0
# production_budget    0
# domestic_gross       0
# worldwide_gross      0
# dtype: int64

# %% [markdown]
# **The 'movie_budgets' dataset does not have any missing values**

# %% [markdown]
# **I will first convert the object values in the three columns with budget amounts**
#
# **i.e.('production_budget', 'domestic_gross', 'worldwide_gross') to float values**
#
# **and also remove the $ sign and the comma values**

# %%
#using a for loop to do this
#df[col] = df[col].str.replace(r'[$,]', '', regex=True)
#df[columns_to_convert] = df[columns_to_convert].astype(float)

columns = ['production_budget', 'domestic_gross', 'worldwide_gross']

movie_budgets[columns] = movie_budgets[columns].replace(r'[$,]', '', regex=True).astype('int64')
    
movie_budgets[columns]
# Out:
#       production_budget  domestic_gross  worldwide_gross
# 0             425000000       760507625       2776345279
# 1             410600000       241063875       1045663875
# 2             350000000        42762350        149762350
# 3             330600000       459005868       1403013963
# 4             317000000       620181382       1316721747
# ...                 ...             ...              ...
# 5777               7000               0                0
# 5778               6000           48482           240495
# 5779               5000            1338             1338
# 5780               1400               0                0
# 5781               1100          181041           181041
#
# [5782 rows x 3 columns]

# %%
movie_budgets
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#       production_budget  domestic_gross  worldwide_gross
# 0             425000000       760507625       2776345279
# ...

# %%
movie_budgets.dtypes
# Out:
# id                    int64
# release_date         object
# movie                object
# production_budget     int64
# domestic_gross        int64
# worldwide_gross       int64
# dtype: object

# %% [markdown]
# **TITLE CREW DATASET**

# %%
title_crew.head()
# Out:
#       tconst                      directors              writers
# 0  tt0285252                      nm0899854            nm0899854
# 1  tt0438973                            NaN  nm0175726,nm1802864
# 2  tt0462036                      nm1940585            nm1940585
# 3  tt0835418                      nm0151540  nm0310087,nm0841532
# 4  tt0878654  nm0089502,nm2291498,nm2292011            nm0284943

# %%
title_crew.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 3 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   tconst     146144 non-null  object
#  1   directors  140417 non-null  object
#  2   writers    110261 non-null  object
# dtypes: object(3)
# memory usage: 3.3+ MB

# %%
title_crew.isna().sum()
# Out:
# tconst           0
# directors     5727
# writers      35883
# dtype: int64

# %% [markdown]
# **TITLE CREW DATASET**

# %% [markdown]
# **NAME BASICS DATASET**

# %%
name_basics.head()
# Out:
#       nconst       primary_name  birth_year  death_year  \
# 0  nm0061671  Mary Ellen Bauder         NaN         NaN
# 1  nm0061865       Joseph Bauer         NaN         NaN
# 2  nm0062070         Bruce Baum         NaN         NaN
# 3  nm0062195       Axel Baumann         NaN         NaN
# 4  nm0062798        Pete Baxter         NaN         NaN
#
#                                  primary_profession  \
# 0         miscellaneous,production_manager,producer
# 1        composer,music_department,sound_department
# 2                        miscellaneous,actor,writer
# 3  camera_department,cinematographer,art_department
# 4  production_designer,art_department,set_decorator
#
#                           known_for_titles
# 0  tt0837562,tt2398241,tt0844471,tt0118553
# 1  tt0896534,tt6791238,tt0287072,tt1682940
# 2  tt1470654,tt0363631,tt0104030,tt0102898
# 3  tt0114371,tt2004304,tt1618448,tt1224387
# 4  tt0452644,tt0452692,tt3458030,tt2178256

# %%
name_basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 606648 entries, 0 to 606647
# Data columns (total 6 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   nconst              606648 non-null  object
#  1   primary_name        606648 non-null  object
#  2   birth_year          82736 non-null   float64
#  3   death_year          6783 non-null    float64
#  4   primary_profession  555308 non-null  object
#  5   known_for_titles    576444 non-null  object
# dtypes: float64(2), object(4)
# memory usage: 27.8+ MB

# %% [markdown]
# **Now I will use the 4  CLEANED datasets for my EDA and retrieving my findings for decision making.**
#
# **These are 'title_basics','title_ratings', 'bom_movie_gross' and 'movie_budgets' datasets**

# %% [markdown]
# **What are the best genres**

# %%
#I will use the title_basics 'genres' column (dtype is an object) to find out  
title_basics.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018             87.0          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %%
#i will first convert the object values to  values that can be grouped

#grouped_df = df.groupby('genres')
title_basics.groupby('genres')

# %%
#I will create a new column(genre_split) to work in

#df['genre_split'] = df['genres'].str.split(',')

title_basics['genre_split'] = title_basics['genres'].str.split(',')

# %%
title_basics
# Out:
#            tconst                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146138  tt9916428                          The Secret of China
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# ...

# %% [markdown]
# **grouping by the genres in the new column based on the number of times they appeared in the 140734 films**

# %%
#grouped_genre = df.explode('genre_split').groupby('genre_split').size()

#NB: The explode operation doesn't modify the original DataFrame; it just transforms it for analysis.

grouped_genre = title_basics.explode('genre_split').groupby('genre_split').size()

print(grouped_genre)
# Out:
# genre_split
# Action         10335
# Adult             25
# Adventure       6464
# Animation       2799
# Biography       8722
# Comedy         25312
# Crime           6753
# Documentary    51640
# Drama          49883
# Family          6227
# Fantasy         3516
# Game-Show          4
# History         6225
# Horror         10805
# Music           4314
# Musical         1430
# Mystery         4659
# News            1551
# Reality-TV        98
# Romance         9371
# Sci-Fi          3365
# Short             11
# Sport           2234
# Talk-Show         50
# Thriller       11883
# War             1405
# Western          467
# dtype: int64

# %%
#arranging in descending order

#genre_counts.sort_values(ascending=False)  
#of the total 140734 films in the title basics dataset

grouped_genre.sort_values(ascending=False)
# Out:
# genre_split
# Documentary    51640
# Drama          49883
# Comedy         25312
# Thriller       11883
# Horror         10805
# Action         10335
# Romance         9371
# Biography       8722
# Crime           6753
# Adventure       6464
# Family          6227
# History         6225
# Mystery         4659
# Music           4314
# Fantasy         3516
# Sci-Fi          3365
# Animation       2799
# Sport           2234
# News            1551
# Musical         1430
# War             1405
# Western          467
# Reality-TV        98
# Talk-Show         50
# Adult             25
# Short             11
# Game-Show          4
# dtype: int64

# %%
#finding out how many types of genres there are in total

#using the set() function to fetch only unique elements from the genre lists,
#since sets only contain unique values but in no particular order.

#using the update() method to keep adding new unique genres from the lists in genre_split to the new set

unique_genres = set()
for genres_list in title_basics['genre_split']:
    unique_genres.update(genres_list)

num_unique_genres = len(unique_genres)

print("Number of unique genres:", num_unique_genres)
print("Unique genres:", unique_genres)
# Out:
# Number of unique genres: 27
# Unique genres: {'Thriller', 'Music', 'Action', 'Romance', 'Fantasy', 'Animation', 'Sport', 'War', 'Documentary', 'Comedy', 'Biography', 'History', 'Mystery', 'Short', 'Reality-TV', 'Sci-Fi', 'Adventure', 'Game-Show', 'Western', 'Talk-Show', 'Adult', 'News', 'Crime', 'Family', 'Musical', 'Horror', 'Drama'}

# %%
data = """
Documentary    51640
Drama          49883
Comedy         25312
Thriller       11883
Horror         10805
Action         10335
Romance         9371
Biography       8722
Crime           6753
Adventure       6464
Family          6227
History         6225
Mystery         4659
Music           4314
Fantasy         3516
Sci-Fi          3365
Animation       2799
Sport           2234
News            1551
Musical         1430
War             1405
Western          467
Reality-TV        98
Talk-Show         50
Adult             25
Short             11
Game-Show          4
"""

# Initialize empty lists for genres and counts
genres = []
counts = []

# Split the data by lines
lines = data.strip().split('\n')

# Iterate through each line and split into genre and count
for line in lines:
    genre, count = line.split()
    genres.append(genre)
    counts.append(int(count))

# Now 'genres' and 'counts' contain the separated data
print(genres)
print(counts)
# Out:
# ['Documentary', 'Drama', 'Comedy', 'Thriller', 'Horror', 'Action', 'Romance', 'Biography', 'Crime', 'Adventure', 'Family', 'History', 'Mystery', 'Music', 'Fantasy', 'Sci-Fi', 'Animation', 'Sport', 'News', 'Musical', 'War', 'Western', 'Reality-TV', 'Talk-Show', 'Adult', 'Short', 'Game-Show']
# [51640, 49883, 25312, 11883, 10805, 10335, 9371, 8722, 6753, 6464, 6227, 6225, 4659, 4314, 3516, 3365, 2799, 2234, 1551, 1430, 1405, 467, 98, 50, 25, 11, 4]

# %% [markdown]
# **I will represent this findings in a bar chart for better visualization**

# %%
plt.figure(figsize=(10, 6))  
plt.barh(genres, counts, color='skyblue')
plt.xlabel('Counts')
plt.ylabel('Genres')
plt.title('Genre Counts from the title_basics dataset (Descending Order)')

plt.show()

# %% [markdown]
# **From this output, the findings are:**
#
# **The Top 6 best performing genres based on frequency of occurence from the 'title_basics' dataset are as follows,**
#
# **in descending order:**
#
# **1. Documentary**
#
# **2. Drama**
#
# **3. Comedy**
#
# **4. Thriller**
#
# **5. Horror**
#
# **6. Action**

# %%
title_ratings
# Out:
#            tconst  averagerating  numvotes
# 0      tt10356526            8.3        31
# 1      tt10384606            8.9       559
# 2       tt1042974            6.4        20
# 3       tt1043726            4.2     50352
# 4       tt1060240            6.5        21
# ...           ...            ...       ...
# 73851   tt9805820            8.1        25
# 73852   tt9844256            7.5        24
# 73853   tt9851050            4.7        14
# 73854   tt9886934            7.0         5
# 73855   tt9894098            6.3       128
#
# [73856 rows x 3 columns]

# %% [markdown]
# **The number of films that were rated are 73856**
#
# **the tconst column values represent thealphanumeric unique identifier of the film title**

# %%
#finding unique values
title_ratings['tconst'].unique()
# Out:
# array(['tt10356526', 'tt10384606', 'tt1042974', ..., 'tt9851050',
#        'tt9886934', 'tt9894098'], dtype=object)

# %%
len(title_ratings['tconst'].unique())
# Out:
# 73856

# %% [markdown]
# **All the titles are unique**

# %% [markdown]
# **the 'tconst' column is in two datasets, 'title_basics' and 'title_ratings'**
#
# **I will create a dataframe that joins this column from the two data sets**
#
# **'title_basics' and 'title_ratings have 140734 and 73856 rows respectively**

# %%
# Filter dataframes by performing a inner join with join()

merged_df =title_basics.set_index('tconst').join(title_ratings.set_index('tconst'), how='inner')
merged_df
# Out:
#                              primary_title              original_title  \
# tconst
# tt0063540                        Sunghursh                   Sunghursh
# tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# tt0069049       The Other Side of the Wind  The Other Side of the Wind
# tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# tt0100275         The Wandering Soap Opera       La Telenovela Errante
# ...                                    ...                         ...
# tt9913056                     Swarm Season                Swarm Season
# tt9913084                 Diabolik sono io            Diabolik sono io
# tt9914286                Sokagin Çocuklari           Sokagin Çocuklari
# tt9914642                        Albatross                   Albatross
# tt9916160                       Drømmeland                  Drømmeland
#
#            start_year  runtime_minutes                genres  \
# tconst
# ...

# %% [markdown]
# **'title_basics' has 6 columns while 'title_ratings' has 3 columns, both dataframes are merged using the 'tconst' column**

# %%
merged_df.isna().sum()
# Out:
# primary_title      0
# original_title     0
# start_year         0
# runtime_minutes    0
# genres             0
# genre_split        0
# averagerating      0
# numvotes           0
# dtype: int64

# %% [markdown]
# **I want to group the the films based on rating using low,medium,high arguments, using a for loop**

# %%
# first sorting out the 'averagerating' column in descending order

merged_df.sort_values(by='averagerating', ascending=False, inplace=True)

# %%
low_rating = 5.0
high_rating = 8.0
# Create a new column to store the categories
merged_df['rating_category'] = None

def categorize_rating(rating):
    if rating < low_rating:
        return 'low'
    elif low_rating <= rating < high_rating:
        return 'medium'
    else:
        return 'high'

# Create a new 'rating_category' column using apply
merged_df['rating_category'] = merged_df['averagerating'].apply(categorize_rating)

print(merged_df['rating_category'])
# Out:
# tconst
# tt1770682    high
# tt5390098    high
# tt7259300    high
# tt4109192    high
# tt4960818    high
#              ...
# tt6018006     low
# tt6017238     low
# tt5277828     low
# tt8176282     low
# tt3235258     low
# Name: rating_category, Length: 73052, dtype: object

# %%
merged_df
# Out:
#                                  primary_title  \
# tconst
# tt1770682                 Freeing Bernie Baran
# tt5390098  The Paternal Bond: Barbary Macaques
# tt7259300                       Calamity Kevin
# tt4109192                I Was Born Yesterday!
# tt4960818                      Revolution Food
# ...                                        ...
# tt6018006                  6 elementov vremeni
# tt6017238          Priklyucheniya Volodi Zlogo
# tt5277828                       Death Forest 3
# tt8176282                  Des figues en avril
# tt3235258                        My First Love
#
#                                               original_title  start_year  \
# tconst
# tt1770682                               Freeing Bernie Baran        2010
# tt5390098  Atlas Mountain: Barbary Macaques - Childcaring...        2015
# tt7259300                                     Calamity Kevin        2019
# tt4109192                              I Was Born Yesterday!        2015
# ...

# %%
#Finding out the number of high rated films in this dataset

high_rated_films = merged_df[merged_df['rating_category'] == 'high']
length_of_high_rated_films = len(high_rated_films)

print("Length of high-rated films:", length_of_high_rated_films)
# Out:
# Length of high-rated films: 9326

# %%
# dataframe to show the 9326 highest rated films
high_rated_films = merged_df[merged_df['rating_category'] == 'high']
high_rated_films
# Out:
#                                    primary_title  \
# tconst
# tt1770682                   Freeing Bernie Baran
# tt5390098    The Paternal Bond: Barbary Macaques
# tt7259300                         Calamity Kevin
# tt4109192                  I Was Born Yesterday!
# tt4960818                        Revolution Food
# ...                                          ...
# tt4911324                 Miracles on the Plains
# tt5687204       Most of the Souls That Live Here
# tt6571274                          When She Runs
# tt9597752                       Tscharniblues II
# tt5195268  Ayrton: Retratos e Memórias - O Filme
#
#                                               original_title  start_year  \
# tconst
# tt1770682                               Freeing Bernie Baran        2010
# tt5390098  Atlas Mountain: Barbary Macaques - Childcaring...        2015
# tt7259300                                     Calamity Kevin        2019
# ...

# %% [markdown]
# **This shows that 9326/73052 films had a high rating i.e 8.0 and above**
#
# **This would however be biased given that the number of votes seem to vary e.g. a film might have a high rating**
#
# **yet only few votes were cast**

# %%
#selecting the first 10 highly rated films

first_5_high_rated_films = high_rated_films.head(10)

first_5_high_rated_films
# Out:
#                                              primary_title  \
# tconst
# tt1770682                             Freeing Bernie Baran
# tt5390098              The Paternal Bond: Barbary Macaques
# tt7259300                                   Calamity Kevin
# tt4109192                            I Was Born Yesterday!
# tt4960818                                  Revolution Food
# tt10378660       The Dark Knight: The Ballad of the N Word
# tt5344358                                    All Around Us
# tt8730716                    Pick It Up! - Ska in the '90s
# tt4944240                        Dog Days in the Heartland
# tt10176328  Exteriores: Mulheres Brasileiras na Diplomacia
#
#                                                original_title  start_year  \
# tconst
# tt1770682                                Freeing Bernie Baran        2010
# tt5390098   Atlas Mountain: Barbary Macaques - Childcaring...        2015
# ...

# %% [markdown]
# **A less biased way of looking at the best rated films would be to consider how many viewers actually cast a vote and base the ratings on that**
#
# **After looking at the viewers votes, the genres which were highly rated would also give an even clearer perspective**

# %%
#sorting out the 'numvotes' column in descending order and base the rating on the number of votes cast

# It also gives me a clue on the viewership status ie. films with the highest number of viewers' votes


merged_df.sort_values(by='numvotes', ascending=False, inplace=True)

# %%
merged_df
# Out:
#                             primary_title                  original_title  \
# tconst
# tt1375666                       Inception                       Inception
# tt1345836           The Dark Knight Rises           The Dark Knight Rises
# tt0816692                    Interstellar                    Interstellar
# tt1853728                Django Unchained                Django Unchained
# tt0848228                    The Avengers                    The Avengers
# ...                                   ...                             ...
# tt3105014                          Hybrid                          Hybrid
# tt1546985  Heaven and Earth and Joe Davis  Heaven and Earth and Joe Davis
# tt2267432             The Eighteenth Hour             The Eighteenth Hour
# tt2507908                        Hot Tuna                        Hot Tuna
# tt1770682            Freeing Bernie Baran            Freeing Bernie Baran
#
#            start_year  runtime_minutes                   genres  \
# ...

# %%
#Top 10 best films based on the viewers' votes

best_films= merged_df.head(10)
best_films
# Out:
#                      primary_title           original_title  start_year  \
# tconst
# tt1375666                Inception                Inception        2010
# tt1345836    The Dark Knight Rises    The Dark Knight Rises        2012
# tt0816692             Interstellar             Interstellar        2014
# tt1853728         Django Unchained         Django Unchained        2012
# tt0848228             The Avengers             The Avengers        2012
# tt0993846  The Wolf of Wall Street  The Wolf of Wall Street        2013
# tt1130884           Shutter Island           Shutter Island        2010
# tt2015381  Guardians of the Galaxy  Guardians of the Galaxy        2014
# tt1431045                 Deadpool                 Deadpool        2016
# tt1392170         The Hunger Games         The Hunger Games        2012
#
#            runtime_minutes                   genres  \
# tconst
# tt1375666            148.0  Action,Adventure,Sci-Fi
# ...

# %% [markdown]
# **I will then group the 10 best performing films based on the genres**

# %%
#group by the 10 best films based on genres

best_genres = best_films.explode('genre_split').groupby('genre_split').size()

print(best_genres)
# Out:
# genre_split
# Action       6
# Adventure    6
# Biography    1
# Comedy       2
# Crime        1
# Drama        3
# Mystery      1
# Sci-Fi       4
# Thriller     2
# Western      1
# dtype: int64

# %%
#sorting in descending order

best_genres.sort_values(ascending=False)
# Out:
# genre_split
# Adventure    6
# Action       6
# Sci-Fi       4
# Drama        3
# Thriller     2
# Comedy       2
# Western      1
# Mystery      1
# Crime        1
# Biography    1
# dtype: int64

# %% [markdown]
# **This output above gives a clearer picture of the highest ratings based on the viewers' votes and the genre.**
#
# **It shows that the 10 best performing films had higher viewership and were given a higher rating**
#
# **It also shows that from the genres of the 10 best performing films, viewers liked Action, Adventure and Scifi films most**

# %% [markdown]
# **I will represent this in a bar chart**

# %%
genre_frequencies = {
    'Adventure': 6,
    'Action': 6,
    'Sci-Fi': 4,
    'Drama': 3,
    'Thriller': 2,
    'Comedy': 2,
    'Western': 1,
    'Mystery': 1,
    'Crime': 1,
    'Biography': 1
}

# Extract genres and counts from the dictionary
genres = list(genre_frequencies.keys())
counts = list(genre_frequencies.values())

# Create a bar chart
plt.figure(figsize=(10,6))
plt.bar(genres, counts)
plt.xlabel('Genres')
plt.ylabel('Frequency')
plt.title('Genre Frequencies of the 10 best performing films')

plt.show()

# %% [markdown]
# **I will create a dataframe merging the title and movie columns using alias in the 'bom_movie_gross' dataset and the 'movie_budgets' then use it to find out information about profits made**

# %%
   bom_movie_gross
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#       foreign_gross  year
# ...

# %%
movie_budgets
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#       production_budget  domestic_gross  worldwide_gross
# 0             425000000       760507625       2776345279
# ...

# %%
#fetching only the matching records under the 'movie' and 'title' columns
gross_df =movie_budgets.set_index('movie').join(bom_movie_gross.set_index('title'), how='inner', lsuffix='_budgets', rsuffix='_gross')
gross_df
# Out:
#                                            id  release_date  \
# 10 Cloverfield Lane                        54  Mar 11, 2016
# 12 Strong                                  64  Jan 19, 2018
# 12 Years a Slave                           18  Oct 18, 2013
# 127 Hours                                   6   Nov 5, 2010
# 13 Hours: The Secret Soldiers of Benghazi  30  Jan 15, 2016
# ...                                        ..           ...
# Zookeeper                                  71   Jul 8, 2011
# Zoolander 2                                64  Feb 12, 2016
# Zootopia                                   57   Mar 4, 2016
# [Rec] 2                                    13   Jul 9, 2010
# mother!                                    59  Sep 15, 2017
#
#                                            production_budget  \
# 10 Cloverfield Lane                                  5000000
# 12 Strong                                           35000000
# ...

# %%
#These are the top 10 best performing films overall
best_films
# Out:
#                      primary_title           original_title  start_year  \
# tconst
# tt1375666                Inception                Inception        2010
# tt1345836    The Dark Knight Rises    The Dark Knight Rises        2012
# tt0816692             Interstellar             Interstellar        2014
# tt1853728         Django Unchained         Django Unchained        2012
# tt0848228             The Avengers             The Avengers        2012
# tt0993846  The Wolf of Wall Street  The Wolf of Wall Street        2013
# tt1130884           Shutter Island           Shutter Island        2010
# tt2015381  Guardians of the Galaxy  Guardians of the Galaxy        2014
# tt1431045                 Deadpool                 Deadpool        2016
# tt1392170         The Hunger Games         The Hunger Games        2012
#
#            runtime_minutes                   genres  \
# tconst
# tt1375666            148.0  Action,Adventure,Sci-Fi
# ...

# %% [markdown]
# **I will then create a new dataframe that gives matching records of the highest rated films from the 'best_films' dataset(10 films) with the 'gross_df' dataset (1244 films)**

# %%
# Perform a join using the index from df1 and the 'title' column from df2
#result = df1.join(df2.set_index('title'), how='inner')
matching_films_df = gross_df.join(best_films.set_index('primary_title'), how= 'inner')
matching_films_df
# Out:
#                          id  release_date  production_budget  \
# Deadpool                 56  Feb 12, 2016           58000000
# Django Unchained         69  Dec 25, 2012          100000000
# Guardians of the Galaxy  14   Aug 1, 2014          170000000
# Inception                38  Jul 16, 2010          160000000
# Interstellar             32   Nov 5, 2014          165000000
# Shutter Island           52  Feb 19, 2010           80000000
# The Dark Knight Rises    11  Jul 20, 2012          275000000
# The Hunger Games         38  Mar 23, 2012           80000000
# The Wolf of Wall Street  76  Dec 25, 2013          100000000
#
#                          domestic_gross_budgets  worldwide_gross studio  \
# Deadpool                              363070709        801025593    Fox
# Django Unchained                      162805434        449948323  Wein.
# Guardians of the Galaxy               333172112        770867516     BV
# ...

# %% [markdown]
# **I have now retrieved 9/10 best performing films with their gross budgets and profits**

# %%
#Calculating the average amount in millions for bugdets and for profits made from the best performing films
matching_films_df[['original_title', 'production_budget', 'domestic_gross_budgets', 'worldwide_gross', 'domestic_gross_gross', 'foreign_gross' ]].mean().astype(int)
# Out:
# production_budget         132000000
# domestic_gross_budgets    271189529
# worldwide_gross           663937791
# domestic_gross_gross      271188888
# foreign_gross             390333333
# dtype: int32

# %% [markdown]
# **The average amount in million dollars that would be needed to create a great film would be a
# **production budget of 132M**
#
# **The estimated average earnings in million dollars were as follows:**
# **worldwide gross 663M, domestic gross 271M and foreign gross 390M**

# %% [markdown]
# **Definition of terms according to Wikipedia**
#
# **Production Budget: This budget accounts for the costs incurred during the actual filming process,**
# **such as equipment rentals, crew salaries, and set design.**
#
# **The worldwide gross in movies refers to the total revenue generated by a film from all sources worldwide,**
# **including ticket sales, merchandise, licensing, and distribution deals.**
# **It is a measure of a movie's overall financial success.**
#
# **Domestic" gross refers to gross box-office revenue from North America countries i.e. U.S., Canada, and Puerto Rico.**
#
# **Foreign gross includes all other countries in North America.**

# %% [markdown]
# **I want to compare the production budgets and the profits of these films**

# %% [markdown]
# **I will represent this in a bar chart for better visualization**

# %%
data = matching_films_df[['original_title', 'production_budget', 'domestic_gross_budgets', 'worldwide_gross', 'domestic_gross_gross', 'foreign_gross']]

# Sample data
column_names = ['original_title', 'production_budget', 'domestic_gross_budgets', 'worldwide_gross', 'domestic_gross_gross', 'foreign_gross']

# Create a DataFrame from the data with column names
df = pd.DataFrame(data, columns=column_names)

# Set the 'Film' column as the index
df.set_index('original_title', inplace=True)

# Create a bar chart
df.plot(kind='bar', figsize=(12, 10))
plt.title('Comparison of Films by production_budget, domestic_gross_budgets, worldwide_gross, domestic_gross_gross, foreign_gross', y=1.1)

plt.xlabel('Films')
plt.ylabel('Amount in Millions')

# Show the plot
plt.show()

# %% [markdown]
# **This figure shows a summary of the budgets per film and the gross profits**

# %% [markdown]
# **In conclusion, the findings showed the best genres from the top 9 best performing films were from the Adventure,Action and Scifi genres and had  the highest ratings based on the viewers' votes, and the gross budgets accrued with the gross profits made for each of those films**

# %% [markdown]
# **Based on these findings, my recommendatiion is that the genres, the viewer ratings, the budgets and estimated profit margins are important factors to consider when Microsoft embarks on their new venture of creating a new movie studio.**
